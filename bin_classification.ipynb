# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression 
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\py-master\ML\7_logistic_reg\insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
#plotting grap using scatter plot
plt.figure(figsize=[5,3])
plt.scatter(df.age, df.bought_insurance)
plt.xlabel("Age")
plt.ylabel("bought_insurance")
# Out:
# Text(0, 0.5, 'bought_insurance')

# %%
#splitting the data set
X_train, x_test, Y_train, y_test = train_test_split(df[["age"]], df["bought_insurance"], test_size=0.1)

# %%
model = LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
model.predict([[15]])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
model.score(X_train,Y_train)
# Out:
# 0.9166666666666666
