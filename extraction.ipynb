# %%
import pandas as pd

# %%
#extrating info from below website
df =pd.read_html('https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)')

# %%
#checking the no of tables in the website 
len(df)
# Out:
# 24

# %%
#extracting the second table
df[1]
# Out:
#     No. overall  No. in season                                Title  \
# 0             1              1  "Simpsons Roasting on an Open Fire"
# 1             2              2                    "Bart the Genius"
# 2             3              3                    "Homer's Odyssey"
# 3             4              4      "There's No Disgrace Like Home"
# 4             5              5                   "Bart the General"
# 5             6              6                       "Moaning Lisa"
# 6             7              7           "The Call of the Simpsons"
# 7             8              8                  "The Telltale Head"
# 8             9              9              "Life on the Fast Lane"
# 9            10             10                  "Homer's Night Out"
# 10           11             11                "The Crepes of Wrath"
# 11           12             12                 "Krusty Gets Busted"
# 12           13             13             "Some Enchanted Evening"
#
# ...

# %%
#reading file from Html directly
df1 = pd.read_html("https://en.wikipedia.org/wiki/Jumong_(TV_series)")

# %%
df1[1]
# Out:
#           Date  Episode   Nationwide        Seoul
# 0   2006-05-15        1  16.3% (3rd)  17.5% (3rd)
# 1   2006-05-16        2  18.4% (3rd)  19.2% (3rd)
# 2   2006-05-22        3  21.8% (1st)  23.6% (1st)
# 3   2006-05-23        4  25.3% (2nd)  26.6% (2nd)
# 4   2006-05-29        5  28.0% (1st)  29.9% (1st)
# ..         ...      ...          ...          ...
# 77  2007-02-26       78  47.2% (1st)  47.1% (1st)
# 78  2007-02-27       79  50.6% (1st)  50.9% (1st)
# 79  2007-03-05       80  49.8% (1st)  50.0% (1st)
# 80  2007-03-06       81  51.9% (1st)  52.7% (1st)
# 81     Average  Average       40.98%       41.83%
#
# [82 rows x 4 columns]

# %%
#download cvs file from the internet using pandas 
league25 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/E0.csv")
league25
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  16/08/2024  20:00     Man United       Fulham     1     0   H     0
# 1    E0  17/08/2024  12:30        Ipswich    Liverpool     0     2   A     0
# 2    E0  17/08/2024  15:00        Arsenal       Wolves     2     0   H     1
# 3    E0  17/08/2024  15:00        Everton     Brighton     0     3   A     0
# 4    E0  17/08/2024  15:00      Newcastle  Southampton     1     0   H     1
# ..   ..         ...    ...            ...          ...   ...   ...  ..   ...
# 105  E0  09/11/2024  20:00      Liverpool  Aston Villa     2     0   H     1
# 106  E0  10/11/2024  14:00     Man United    Leicester     3     0   H     2
# 107  E0  10/11/2024  14:00  Nott'm Forest    Newcastle     1     3   A     1
# 108  E0  10/11/2024  14:00      Tottenham      Ipswich     1     2   A     0
# 109  E0  10/11/2024  16:30        Chelsea      Arsenal     1     1   D     0
#
# ...

# %%
#renaming some column
league25.rename({"FTHG": "Home_goal",
                           "FTAG":"Away_goal"}, inplace=True)

# %%
print(league25)
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  16/08/2024  20:00     Man United       Fulham     1     0   H     0
# 1    E0  17/08/2024  12:30        Ipswich    Liverpool     0     2   A     0
# 2    E0  17/08/2024  15:00        Arsenal       Wolves     2     0   H     1
# 3    E0  17/08/2024  15:00        Everton     Brighton     0     3   A     0
# 4    E0  17/08/2024  15:00      Newcastle  Southampton     1     0   H     1
# ..   ..         ...    ...            ...          ...   ...   ...  ..   ...
# 105  E0  09/11/2024  20:00      Liverpool  Aston Villa     2     0   H     1
# 106  E0  10/11/2024  14:00     Man United    Leicester     3     0   H     2
# 107  E0  10/11/2024  14:00  Nott'm Forest    Newcastle     1     3   A     1
# 108  E0  10/11/2024  14:00      Tottenham      Ipswich     1     2   A     0
# 109  E0  10/11/2024  16:30        Chelsea      Arsenal     1     1   D     0
#
# ...

# %%
#saving the extracted file into my local folder in csv format
league25.to_csv(r"C:\Users\HP\Desktop\data science folder\League_25.csv")

# %%
import camelot

# %%
#imoprting table from pdf file using camelot
table = camelot.read_pdf("C:\\Users\\HP\\Desktop\\foo.pdf", pages='1')

# %%
print(table)
# Out:
# <TableList n=1>

# %%
table.export("foo.csv", f="csv", compress=True)
table[0].to_csv("C:\\Users\\HP\\Desktop\\data science folder\\foo.csv")
